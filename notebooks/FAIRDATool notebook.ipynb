# %%
import re
import numpy as np
import pandas as pd
import json
import os

basedir = "%s/%s" % (os.getenv("HOME"), "fair-datool")
datadir = "%s/data" % basedir

# %%
def readmetrics(filename):
    dataframe = pd.read_csv("%s/%s" % (datadir, filename))
    metrics = dataframe 
    metrics = metrics.replace(np.nan, '', regex=True)
    return metrics

metrics = readmetrics('Metrics.csv')
metrics
# Out:
#     F1a  F1b  F2a   F2b  F3a  F3b  F3c  F4a  F4b  F5a  F5b    F
# 0    No                             No                        1
# 1    No                            Yes                        3
# 2   Yes                        No                             2
# 3   Yes                       Yes                 Yes         5
# 4   Yes                       Yes                  No         4
# 5
# 6   A1a  A1b  A2a   A2b  A3a  A3b  A4a  A4b  A5a  A5b         A
# 7    No   No                                                  1
# 8    No  Yes                                                  2
# 9   Yes                   No                                  5
# 10  Yes                  Yes        No                        3
# 11  Yes                  Yes       Yes                        4
# 12
# 13   I0  I1a  I1b   I2a  I2b  I3a  I3b  I4a  I4b  I5a  I5b    I
# 14  Yes       Yes                                             1
# 15  Yes        No  Most                                     1.5
# 16  Yes        No  Half                                       2
# 17  Yes        No   Few                                     2.5
# 18  Yes        No  None                       No              3
# 19  Yes       No   None                      Yes   No         4
# 20  Yes        No  None                      Yes  Yes         5
# 21   No  Yes                                                  1
# 22   No   No                   No                             2
# 23   No   No                  Yes             No              3
# 24   No   No                  Yes            Yes  Yes         5
# 25   No   No                  Yes            Yes   No         4

# %% [raw]
# Now we will read codes

# %%
def readcodes(filename):
    dataframe = pd.read_csv("%s/%s" % (datadir, filename), names=['Question', 'Code','Reference'])
    codes = dataframe 
    return codes

codes = readcodes('Codes.csv')
q1 = "Is the data file in a proprietary format?"
x = codes[codes['Question'] == q1]
codes
# Out:
#                                              Question Code  \
# 0   Does the dataset have a persistent identifier ...  F1a
# 1   Is there sufficient metadata/documentation ava...  F3b
# 2   Is there sufficient metadata/documentation ava...  F3c
# 3   Is there extensive metadata and rich additiona...  F5a
# 4              Does the dataset have a user license?   A1a
# 5                        Are the metadata accessible?  A1b
# 6   Does the user license have any user restrictio...  A3a
# 7   Is the dataset available for public access? (i...  A4a
# 8                          Is the dataset multi-file?   I0
# 9           Is the data file in a proprietary format?  I1a
# 10  Are all of the data files in a proprietary for...  I1b
# 11  Is the format therefore consistent with a 'pre...  I3a
# 12  Please indicate which of these statements is t...  I2a
# 13  Is a standardised vocabulary, coding scheme or...  I4b
# 14  Is the data represented as linked data (e.g. i...  I5a
# 15  In the box below you can record your overall v...  NaN
# 16  Finally how long did it take you to complete t...  NaN
#
#                                             Reference
# 0   https://docs.google.com/document/d/1bRQDN_VFSP...
# 1   https://docs.google.com/document/d/1bRQDN_VFSP...
# 2   https://docs.google.com/document/d/1bRQDN_VFSP...
# 3   https://docs.google.com/document/d/1bRQDN_VFSP...
# 4   https://docs.google.com/document/d/1bRQDN_VFSP...
# 5   https://docs.google.com/document/d/1bRQDN_VFSP...
# 6   https://docs.google.com/document/d/1bRQDN_VFSP...
# 7   https://docs.google.com/document/d/1bRQDN_VFSP...
# 8                                                 NaN
# 9   https://docs.google.com/document/d/1bRQDN_VFSP...
# 10  https://docs.google.com/document/d/1bRQDN_VFSP...
# 11  https://docs.google.com/document/d/1bRQDN_VFSP...
# 12  https://docs.google.com/document/d/1bRQDN_VFSP...
# 13  https://docs.google.com/document/d/1bRQDN_VFSP...
# 14  https://docs.google.com/document/d/1bRQDN_VFSP...
# 15                                                NaN
# 16                                                NaN

# %%
filename = "datasample1.csv"
dataframe = pd.read_csv("%s/%s" % (datadir, filename))
def get_mappings(dataframe):
    mapping = {}
    newcolumns = []
    for q in dataframe.columns:
        findcode = codes[codes['Question'] == q]
        if findcode['Code'].any():
            mapping[q] = findcode['Code'].values[0]
            newcolumns.append(mapping[q])
        else:
            newcolumns.append(q)
            #print "%s %s" % (q, findcode['Code'].values[0])
    return (mapping, newcolumns)

(mapping, newcols) = get_mappings(dataframe)
dataframe.columns = newcols

# %%
doi = "https://doi.org/10.17026%2Fdans-xt6-swmq"
def find_datasets(doi):
    doikey = "Please enter the PID of the dataset you are going to review:(i.e. https://doi.org/10.1000/xyz123)"
    thisdata = dataframe[dataframe[doikey] == doi]
    #print x.columns
    return thisdata

thisdata = find_datasets(doi)

#for datarow in metrics.index:
    #print metrics.ix[datarow]
print thisdata.columns
# Out:
# F1a    No
# F1b
# F2a
# F2b
# F3a
# F3b
# F3c    No
# F4a
# F4b
# F5a
# F5b
# F       1
# Name: 0, dtype: object
# F1a     No
# F1b
# F2a
# F2b
# F3a
# F3b
# F3c    Yes
# F4a
# F4b
# F5a
# F5b
# F        3
# Name: 1, dtype: object
# F1a    Yes
# F1b
# F2a
# F2b
# F3a
# F3b     No
# F3c
# F4a
# F4b
# F5a
# F5b
# F        2
# Name: 2, dtype: object
# F1a    Yes
# F1b
# F2a
# F2b
# F3a
# F3b    Yes
# F3c
# F4a
# F4b
# F5a    Yes
# F5b
# F        5
# Name: 3, dtype: object
# F1a    Yes
# F1b
# F2a
# F2b
# F3a
# F3b    Yes
# F3c
# F4a
# F4b
# F5a     No
# F5b
# F        4
# Name: 4, dtype: object
# F1a
# F1b
# F2a
# F2b
# F3a
# F3b
# F3c
# F4a
# F4b
# F5a
# F5b
# F
# Name: 5, dtype: object
# F1a    A1a
# F1b    A1b
# F2a    A2a
# F2b    A2b
# F3a    A3a
# F3b    A3b
# F3c    A4a
# F4a    A4b
# F4b    A5a
# F5a    A5b
# F5b
# F        A
# Name: 6, dtype: object
# F1a    No
# F1b    No
# F2a
# F2b
# F3a
# F3b
# F3c
# F4a
# F4b
# F5a
# F5b
# F       1
# Name: 7, dtype: object
# F1a     No
# F1b    Yes
# F2a
# F2b
# F3a
# F3b
# F3c
# F4a
# F4b
# F5a
# F5b
# F        2
# Name: 8, dtype: object
# F1a    Yes
# F1b
# F2a
# F2b
# F3a     No
# F3b
# F3c
# F4a
# F4b
# F5a
# F5b
# F        5
# Name: 9, dtype: object
# F1a    Yes
# F1b
# F2a
# F2b
# F3a    Yes
# F3b
# F3c     No
# F4a
# F4b
# F5a
# F5b
# F        3
# Name: 10, dtype: object
# F1a    Yes
# F1b
# F2a
# F2b
# F3a    Yes
# F3b
# F3c    Yes
# F4a
# F4b
# F5a
# F5b
# F        4
# Name: 11, dtype: object
# F1a
# F1b
# F2a
# F2b
# F3a
# F3b
# F3c
# F4a
# F4b
# F5a
# F5b
# F
# Name: 12, dtype: object
# F1a     I0
# F1b    I1a
# F2a    I1b
# F2b    I2a
# F3a    I2b
# F3b    I3a
# F3c    I3b
# F4a    I4a
# F4b    I4b
# F5a    I5a
# F5b    I5b
# F        I
# Name: 13, dtype: object
# F1a    Yes
# F1b
# F2a    Yes
# F2b
# F3a
# F3b
# F3c
# F4a
# F4b
# F5a
# F5b
# F        1
# Name: 14, dtype: object
# F1a     Yes
# F1b
# F2a      No
# F2b    Most
# F3a
# F3b
# F3c
# F4a
# F4b
# F5a
# F5b
# F       1.5
# Name: 15, dtype: object
# F1a     Yes
# F1b
# F2a      No
# F2b    Half
# F3a
# F3b
# F3c
# F4a
# F4b
# F5a
# F5b
# F         2
# Name: 16, dtype: object
# F1a    Yes
# F1b
# F2a     No
# F2b    Few
# F3a
# F3b
# F3c
# F4a
# F4b
# F5a
# F5b
# F      2.5
# Name: 17, dtype: object
# F1a     Yes
# F1b
# F2a      No
# F2b    None
# F3a
# F3b
# F3c
# F4a
# F4b      No
# F5a
# F5b
# F         3
# Name: 18, dtype: object
# F1a     Yes
# F1b
# F2a     No
# F2b    None
# F3a
# F3b
# F3c
# F4a
# F4b     Yes
# F5a      No
# F5b
# F         4
# Name: 19, dtype: object
# F1a     Yes
# F1b
# F2a      No
# F2b    None
# F3a
# F3b
# F3c
# F4a
# F4b     Yes
# F5a     Yes
# F5b
# F         5
# Name: 20, dtype: object
# F1a     No
# F1b    Yes
# F2a
# F2b
# F3a
# F3b
# F3c
# F4a
# F4b
# F5a
# F5b
# F        1
# Name: 21, dtype: object
# F1a    No
# F1b    No
# F2a
# F2b
# F3a
# F3b    No
# F3c
# F4a
# F4b
# F5a
# F5b
# F       2
# Name: 22, dtype: object
# F1a     No
# F1b     No
# F2a
# F2b
# F3a
# F3b    Yes
# F3c
# F4a
# F4b     No
# F5a
# F5b
# F        3
# Name: 23, dtype: object
# F1a     No
# F1b     No
# F2a
# F2b
# F3a
# F3b    Yes
# F3c
# F4a
# F4b    Yes
# F5a    Yes
# F5b
# F        5
# Name: 24, dtype: object
# F1a     No
# F1b     No
# F2a
# F2b
# F3a
# F3b    Yes
# F3c
# F4a
# F4b    Yes
# F5a     No
# F5b
# F        4
# Name: 25, dtype: object
